# %%
# Data Types

#1. Immutable - numeric , string , tuples

#2. Mutable - list , dict , set

# %%
# Tuples - are immutable data type that stores the element comma seperatedly

# tuples are packed into the parenthesis

# %%
t = (1,2,3,4)
print(t,type(t))
# Out:
# (1, 2, 3, 4) <class 'tuple'>

# %%
t1 = ('a','b','c')
print(t1,type(t1))
# Out:
# ('a', 'b', 'c') <class 'tuple'>

# %%
t2=(1,'2','a')
print(t2,type(t2))
# Out:
# (1, '2', 'a') <class 'tuple'>

# %%
t3=('Deepanshu',)
print(t3,type(t3))
# Out:
# ('Deepanshu',) <class 'tuple'>

# %%
t4 = 1,2,3,4,5
print(t4)
# Out:
# (1, 2, 3, 4, 5)

# %%
T1 = ('1234')
# print(len(T1))
for  i in T1:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
T2=('1234',)
# print(len(T2),type(T2))
for i in T2:
    print(i)
# Out:
# 1234

# %%
t = ('a','quick','brown','fox','jumps','over','a','lazy','dog')
print(t,len(t))
# Out:
# ('a', 'quick', 'brown', 'fox', 'jumps', 'over', 'a', 'lazy', 'dog') 9

# %%
# index
print(t.index('a'))
# Out:
# 0

# %%
# count
print(t.count('o'))
# Out:
# 0

# %%
t = (5,2,8,4,9)

print(sorted(t))
print(sorted(t,reverse=True))
print(min(t))
print(max(t))
# Out:
# [2, 4, 5, 8, 9]
# [9, 8, 5, 4, 2]
# 2
# 9

# %%
T=('Z','a','7','z','B','@','I','d',"D"," ")
print(sorted(T))
print(sorted(T,reverse=True))
# Out:
# [' ', '7', '@', 'B', 'D', 'I', 'Z', 'a', 'd', 'z']
# ['z', 'd', 'a', 'Z', 'I', 'D', 'B', '@', '7', ' ']

# %%
for i in T:
    print(i,'.........',ord(i))
# Out:
# Z ......... 90
# a ......... 97
# 7 ......... 55
# z ......... 122
# B ......... 66
# @ ......... 64
# I ......... 73
# d ......... 100
# D ......... 68
#   ......... 32

# %%
print(chr(115))
# Out:
# s

# %%
print(t)
# Out:
# ('a', 'quick', 'brown', 'fox', 'jumps', 'over', 'a', 'lazy', 'dog')

# %%
print(" ".join(t))
# Out:
# a quick brown fox jumps over a lazy dog

# %%
first=('Deepanshu',)
last = ('Verma',)

full = first+last
print(full,type(full))
print(last*2)
# Out:
# ('Deepanshu', 'Verma') <class 'tuple'>
# ('Verma', 'Verma')

# %%
nitin
naman
level
mam
madam
wow
xyz

# %%
s = input('ENTER S ')
if s ==s[::-1]:
    print('Pallindrome')

else:
    print('Not Pallidnrome')
# Out:
# ENTER S  racecar
# Pallindrome

# %%
s = input('enter s ')

if s.isalnum():
    print(False)
else:
    print(True)
# Out:
# enter s  bc456^\
# True

# %%
s = input('enter s ')
X=False
for i in s:
    if ord(i)>=49 and ord(i)<=57:
        pass
    elif ord(i)>=65 and ord(i)<=90:
        pass
    elif ord(i)>=97 and ord(i)<=122:
        pass
    else:
        X=True
        break
                
print(X)
# Out:
# enter s  abcd
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 14
#      11         X=True
#      12         break
# ---> 14 print(X)
#
# NameError: name 'X' is not defined

# %%
ord('z')
# Out:
# 122

# %%
s = 'banana'
x=""

for i in s:
    if i not in x:
        x=x+i
print(x)
# Out:
# ban

# %%
s ='apple'
c=0
for i in s:
    print(i,'.....',c)
    c=c+1
# Out:
# a ..... 0
# p ..... 1
# p ..... 2
# l ..... 3
# e ..... 4

# %%
s ='apple'
for i in range(len(s)):
    print(s[i],'....',i)
# Out:
# a .... 0
# p .... 1
# p .... 2
# l .... 3
# e .... 4

# %%
s ='a quick brown fox jumps over the lazy dog'
# abcde......xyz

# %%
n = int(input('enter how many numbers'))
a = int(input('enter a '))
min = a
max = a

for i in range(n-1):
    a = int(input('enter a '))
    if min<a:
        min=a
    elif max>a:
        max=a

print(min)
print(max)
# Out:
# enter how many numbers 3
# enter a  99
# enter a  -5
# enter a  10
# 99
# -5
